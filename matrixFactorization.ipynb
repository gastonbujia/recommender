# %% [markdown]
# ###  Matrix factorization

# %%
import numpy as np
import pandas as pd
from surprise import Dataset
from surprise import SVD
from surprise import evaluate
from surprise import GridSearch

# %%
path = '~/data/'

# %%
import os
os.getcwd()
# Out:
# '/home/yamila/repos/matrixFactorization/codigo'

# %% [markdown]
# ### Data set
# Movie Lens data set

# %%
data = Dataset.load_builtin('ml-100k')
# si no tenes el data set, lo descarga y lo guarda en la carpeta de data sets de surprise.
# Tambien se puede bajar de http://files.grouplens.org/datasets/movielens/ml-100k.zip

# %%
names = ['user_id','item_id','rating','timestamp']
df = pd.read_csv( 'data/u.data', sep ='\t',names = names)
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596

# %%
n_users = df.user_id.unique().shape[0]
n_items = df.item_id.unique().shape[0]
print('users:'+str(n_users))
print('movies:'+str(n_items))
# Out:
# users:943
# movies:1682

# %% [markdown]
# ### Medidas del error

# %% [markdown]
# Root mean squared error
# $$RMSE = \sqrt{\frac{1}{n} \sum_{(i,j)} (r_{ij}-\hat{r}_{ij})^2}$$
# Mean Absolute error
# $$MAE = \frac{1}{n} \sum_{(i,j)}|r_{ij}-\hat{r}_{ij}|$$

# %%
data.split(n_folds=2)

# %%
help(SVD)
# Out:
# Help on class SVD in module surprise.prediction_algorithms.matrix_factorization:
#
# class SVD(surprise.prediction_algorithms.algo_base.AlgoBase)
#  |  The famous *SVD* algorithm, as popularized by `Simon Funk
#  |  <http://sifter.org/~simon/journal/20061211.html>`_ during the Netflix
#  |  Prize. When baselines are not used, this is equivalent to Probabilistic
#  |  Matrix Factorization :cite:`salakhutdinov2008a` (see :ref:`note
#  |  <unbiased_note>` below).
#  |
#  |  The prediction :math:`\hat{r}_{ui}` is set as:
#  |
#  |  .. math::
#  |      \hat{r}_{ui} = \mu + b_u + b_i + q_i^Tp_u
#  |
#  |  If user :math:`u` is unknown, then the bias :math:`b_u` and the factors
#  |  :math:`p_u` are assumed to be zero. The same applies for item :math:`i`
#  |  with :math:`b_i` and :math:`q_i`.
#  |
#  |  For details, see equation (5) from :cite:`Koren:2009`. See also
#  |  :cite:`Ricci:2010`, section 5.3.1.
#  |
#  |  To estimate all the unknown, we minimize the following regularized squared
#  |  error:
#  |
#  |  .. math::
#  |      \sum_{r_{ui} \in R_{train}} \left(r_{ui} - \hat{r}_{ui} \right)^2 +
#  |      \lambda\left(b_i^2 + b_u^2 + ||q_i||^2 + ||p_u||^2\right)
#  |
#  |
#  |  The minimization is performed by a very straightforward stochastic gradient
#  |  descent:
#  |
#  |  .. math::
#  |      b_u &\leftarrow b_u &+ \gamma (e_{ui} - \lambda b_u)\\
#  |      b_i &\leftarrow b_i &+ \gamma (e_{ui} - \lambda b_i)\\
#  |      p_u &\leftarrow p_u &+ \gamma (e_{ui} \cdot q_i - \lambda p_u)\\
#  |      q_i &\leftarrow q_i &+ \gamma (e_{ui} \cdot p_u - \lambda q_i)
#  |
#  |  where :math:`e_{ui} = r_{ui} - \hat{r}_{ui}`. These steps are performed
#  |  over all the ratings of the trainset and repeated ``n_epochs`` times.
#  |  Baselines are initialized to ``0``. User and item factors are randomly
#  |  initialized according to a normal distribution, which can be tuned using
#  |  the ``init_mean`` and ``init_std_dev`` parameters.
#  |
#  |  You also have control over the learning rate :math:`\gamma` and the
#  |  regularization term :math:`\lambda`. Both can be different for each
#  |  kind of parameter (see below). By default, learning rates are set to
#  |  ``0.005`` and regularization terms are set to ``0.02``.
#  |
#  |  .. _unbiased_note:
#  |
#  |  .. note::
#  |      You can choose to use an unbiased version of this algorithm, simply
#  |      predicting:
#  |
#  |      .. math::
#  |          \hat{r}_{ui} = q_i^Tp_u
#  |
#  |      This is equivalent to Probabilistic Matrix Factorization
#  |      (:cite:`salakhutdinov2008a`, section 2) and can be achieved by setting
#  |      the ``biased`` parameter to ``False``.
#  |
#  |
#  |  Args:
#  |      n_factors: The number of factors. Default is ``100``.
#  |      n_epochs: The number of iteration of the SGD procedure. Default is
#  |          ``20``.
#  |      biased(bool): Whether to use baselines (or biases). See :ref:`note
#  |          <unbiased_note>` above.  Default is ``True``.
#  |      init_mean: The mean of the normal distribution for factor vectors
#  |          initialization. Default is ``0``.
#  |      init_std_dev: The standard deviation of the normal distribution for
#  |          factor vectors initialization. Default is ``0.1``.
#  |      lr_all: The learning rate for all parameters. Default is ``0.005``.
#  |      reg_all: The regularization term for all parameters. Default is
#  |          ``0.02``.
#  |      lr_bu: The learning rate for :math:`b_u`. Takes precedence over
#  |          ``lr_all`` if set. Default is ``None``.
#  |      lr_bi: The learning rate for :math:`b_i`. Takes precedence over
#  |          ``lr_all`` if set. Default is ``None``.
#  |      lr_pu: The learning rate for :math:`p_u`. Takes precedence over
#  |          ``lr_all`` if set. Default is ``None``.
#  |      lr_qi: The learning rate for :math:`q_i`. Takes precedence over
#  |          ``lr_all`` if set. Default is ``None``.
#  |      reg_bu: The regularization term for :math:`b_u`. Takes precedence
#  |          over ``reg_all`` if set. Default is ``None``.
#  |      reg_bi: The regularization term for :math:`b_i`. Takes precedence
#  |          over ``reg_all`` if set. Default is ``None``.
#  |      reg_pu: The regularization term for :math:`p_u`. Takes precedence
#  |          over ``reg_all`` if set. Default is ``None``.
#  |      reg_qi: The regularization term for :math:`q_i`. Takes precedence
#  |          over ``reg_all`` if set. Default is ``None``.
#  |      verbose: If ``True``, prints the current epoch. Default is ``False``.
#  |
#  |  Method resolution order:
#  |      SVD
#  |      surprise.prediction_algorithms.algo_base.AlgoBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, n_factors=100, n_epochs=20, biased=True, init_mean=0, init_std_dev=0.1, lr_all=0.005, reg_all=0.02, lr_bu=None, lr_bi=None, lr_pu=None, lr_qi=None, reg_bu=None, reg_bi=None, reg_pu=None, reg_qi=None, verbose=False)
#  |
#  |  estimate(self, u, i)
#  |
#  |  sgd(self, trainset)
#  |
#  |  train(self, trainset)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from surprise.prediction_algorithms.algo_base.AlgoBase:
#  |
#  |  compute_baselines(self)
#  |      Compute users and items baselines.
#  |
#  |      The way baselines are computed depends on the ``bsl_options`` parameter
#  |      passed at the creation of the algorithm (see
#  |      :ref:`baseline_estimates_configuration`).
#  |
#  |      This method is only relevant for algorithms using :func:`Pearson
#  |      baseline similarty<surprise.similarities.pearson_baseline>` or the
#  |      :class:`BaselineOnly
#  |      <surprise.prediction_algorithms.baseline_only.BaselineOnly>` algorithm.
#  |
#  |      Returns:
#  |          A tuple ``(bu, bi)``, which are users and items baselines.
#  |
#  |  compute_similarities(self)
#  |      Build the similarity matrix.
#  |
#  |      The way the similarity matrix is computed depends on the
#  |      ``sim_options`` parameter passed at the creation of the algorithm (see
#  |      :ref:`similarity_measures_configuration`).
#  |
#  |      This method is only relevant for algorithms using a similarity measure,
#  |      such as the :ref:`k-NN algorithms <pred_package_knn_inpired>`.
#  |
#  |      Returns:
#  |          The similarity matrix.
#  |
#  |  get_neighbors(self, iid, k)
#  |      Return the ``k`` nearest neighbors of ``iid``, which is the inner id
#  |      of a user or an item, depending on the ``user_based`` field of
#  |      ``sim_options`` (see :ref:`similarity_measures_configuration`).
#  |
#  |      As the similarities are computed on the basis of a similarity measure,
#  |      this method is only relevant for algorithms using a similarity measure,
#  |      such as the :ref:`k-NN algorithms <pred_package_knn_inpired>`.
#  |
#  |      For a usage example, see the :ref:`FAQ <get_k_nearest_neighbors>`.
#  |
#  |      Args:
#  |          iid(int): The (inner) id of the user (or item) for which we want
#  |              the nearest neighbors. See :ref:`this note<raw_inner_note>`.
#  |
#  |          k(int): The number of neighbors to retrieve.
#  |
#  |      Returns:
#  |          The list of the ``k`` (inner) ids of the closest users (or items)
#  |          to ``iid``.
#  |
#  |  predict(self, uid, iid, r_ui=None, clip=True, verbose=False)
#  |      Compute the rating prediction for given user and item.
#  |
#  |      The ``predict`` method converts raw ids to inner ids and then calls the
#  |      ``estimate`` method which is defined in every derived class. If the
#  |      prediction is impossible (for whatever reason), the prediction is set
#  |      to the global mean of all ratings.
#  |
#  |      Args:
#  |          uid: (Raw) id of the user. See :ref:`this note<raw_inner_note>`.
#  |          iid: (Raw) id of the item. See :ref:`this note<raw_inner_note>`.
#  |          r_ui(float): The true rating :math:`r_{ui}`. Optional, default is
#  |              ``None``.
#  |          clip(bool): Whether to clip the estimation into the rating scale.
#  |              For example, if :math:`\hat{r}_{ui}` is :math:`5.5` while the
#  |              rating scale is :math:`[1, 5]`, then :math:`\hat{r}_{ui}` is
#  |              set to :math:`5`. Same goes if :math:`\hat{r}_{ui} < 1`.
#  |              Default is ``True``.
#  |          verbose(bool): Whether to print details of the prediction.  Default
#  |              is False.
#  |
#  |      Returns:
#  |          A :obj:`Prediction            <surprise.prediction_algorithms.predictions.Prediction>` object
#  |          containing:
#  |
#  |          - The (raw) user id ``uid``.
#  |          - The (raw) item id ``iid``.
#  |          - The true rating ``r_ui`` (:math:`\hat{r}_{ui}`).
#  |          - The estimated rating (:math:`\hat{r}_{ui}`).
#  |          - Some additional details about the prediction that might be useful
#  |            for later analysis.
#  |
#  |  test(self, testset, verbose=False)
#  |      Test the algorithm on given testset, i.e. estimate all the ratings
#  |      in the given testset.
#  |
#  |      Args:
#  |          testset: A test set, as returned by the :meth:`folds()
#  |              <surprise.dataset.Dataset.folds>` method or by the
#  |              :meth:`build_testset()
#  |              <surprise.dataset.Trainset.build_testset>` method.
#  |          verbose(bool): Whether to print details for each predictions.
#  |              Default is False.
#  |
#  |      Returns:
#  |          A list of :class:`Prediction            <surprise.prediction_algorithms.predictions.Prediction>` objects
#  |          that contains all the estimated ratings.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from surprise.prediction_algorithms.algo_base.AlgoBase:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
algo = SVD(n_factors = 50,
          n_epochs = 20,
          biased = False,
          init_mean = 0,
          init_std_dev = 0.1,
          lr_all = 0.005,
          reg_all = 0.02)
perf = evaluate(algo, data, measures=['RMSE', 'MAE'])
# Out:
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 0.9897
# MAE:  0.7805
# ------------
# Fold 2
# RMSE: 0.9804
# MAE:  0.7712
# ------------
# ------------
# Mean RMSE: 0.9850
# Mean MAE : 0.7759
# ------------
# ------------

# %%
help(evaluate)
# Out:
# Help on function evaluate in module surprise.evaluate:
#
# evaluate(algo, data, measures=['rmse', 'mae'], with_dump=False, dump_dir=None, verbose=1)
#     Evaluate the performance of the algorithm on given data.
#
#     Depending on the nature of the ``data`` parameter, it may or may not
#     perform cross validation.
#
#     Args:
#         algo(:obj:`AlgoBase             <surprise.prediction_algorithms.algo_base.AlgoBase>`):
#             The algorithm to evaluate.
#         data(:obj:`Dataset <surprise.dataset.Dataset>`): The dataset on which
#             to evaluate the algorithm.
#         measures(list of string): The performance measures to compute. Allowed
#             names are function names as defined in the :mod:`accuracy
#             <surprise.accuracy>` module. Default is ``['rmse', 'mae']``.
#         with_dump(bool): If True, the predictions and the algorithm will be
#             dumped for later further analysis at each fold (see :ref:`FAQ
#             <serialize_an_algorithm>`). The file names will be set as:
#             ``'<date>-<algorithm name>-<fold number>'``.  Default is ``False``.
#         dump_dir(str): The directory where to dump to files. Default is
#             ``'~/.surprise_data/dumps/'``.
#         verbose(int): Level of verbosity. If 0, nothing is printed. If 1
#             (default), accuracy measures for each folds are printed, with a
#             final summary. If 2, every prediction is printed.
#
#     Returns:
#         A dictionary containing measures as keys and lists as values. Each list
#         contains one entry per fold.

# %%
algo = SVD(n_factors = 100,
          n_epochs = 20,
          biased = False,
          reg_all = 0.02)
perf = evaluate(algo, data, measures=['RMSE', 'MAE'])

# %%
print(perf)

# %%
param_grid = {'n_factors':[10,50,70,100,200], 'n_epochs' : [20,40,60], 'biased' : [True,False], 'reg_all' : [0.01,0.02,0.03]}
grid_search = GridSearch(SVD, param_grid, measures = ['RMSE','MAE'])
# Out:
# [{'n_factors': 10, 'n_epochs': 20, 'biased': True, 'reg_all': 0.01}, {'n_factors': 10, 'n_epochs': 20, 'biased': True, 'reg_all': 0.02}, {'n_factors': 10, 'n_epochs': 20, 'biased': True, 'reg_all': 0.03}, {'n_factors': 10, 'n_epochs': 20, 'biased': False, 'reg_all': 0.01}, {'n_factors': 10, 'n_epochs': 20, 'biased': False, 'reg_all': 0.02}, {'n_factors': 10, 'n_epochs': 20, 'biased': False, 'reg_all': 0.03}, {'n_factors': 10, 'n_epochs': 40, 'biased': True, 'reg_all': 0.01}, {'n_factors': 10, 'n_epochs': 40, 'biased': True, 'reg_all': 0.02}, {'n_factors': 10, 'n_epochs': 40, 'biased': True, 'reg_all': 0.03}, {'n_factors': 10, 'n_epochs': 40, 'biased': False, 'reg_all': 0.01}, {'n_factors': 10, 'n_epochs': 40, 'biased': False, 'reg_all': 0.02}, {'n_factors': 10, 'n_epochs': 40, 'biased': False, 'reg_all': 0.03}, {'n_factors': 10, 'n_epochs': 60, 'biased': True, 'reg_all': 0.01}, {'n_factors': 10, 'n_epochs': 60, 'biased': True, 'reg_all': 0.02}, {'n_factors': 10, 'n_epochs': 60, 'biased': True, 'reg_all': 0.03}, {'n_factors': 10, 'n_epochs': 60, 'biased': False, 'reg_all': 0.01}, {'n_factors': 10, 'n_epochs': 60, 'biased': False, 'reg_all': 0.02}, {'n_factors': 10, 'n_epochs': 60, 'biased': False, 'reg_all': 0.03}, {'n_factors': 50, 'n_epochs': 20, 'biased': True, 'reg_all': 0.01}, {'n_factors': 50, 'n_epochs': 20, 'biased': True, 'reg_all': 0.02}, {'n_factors': 50, 'n_epochs': 20, 'biased': True, 'reg_all': 0.03}, {'n_factors': 50, 'n_epochs': 20, 'biased': False, 'reg_all': 0.01}, {'n_factors': 50, 'n_epochs': 20, 'biased': False, 'reg_all': 0.02}, {'n_factors': 50, 'n_epochs': 20, 'biased': False, 'reg_all': 0.03}, {'n_factors': 50, 'n_epochs': 40, 'biased': True, 'reg_all': 0.01}, {'n_factors': 50, 'n_epochs': 40, 'biased': True, 'reg_all': 0.02}, {'n_factors': 50, 'n_epochs': 40, 'biased': True, 'reg_all': 0.03}, {'n_factors': 50, 'n_epochs': 40, 'biased': False, 'reg_all': 0.01}, {'n_factors': 50, 'n_epochs': 40, 'biased': False, 'reg_all': 0.02}, {'n_factors': 50, 'n_epochs': 40, 'biased': False, 'reg_all': 0.03}, {'n_factors': 50, 'n_epochs': 60, 'biased': True, 'reg_all': 0.01}, {'n_factors': 50, 'n_epochs': 60, 'biased': True, 'reg_all': 0.02}, {'n_factors': 50, 'n_epochs': 60, 'biased': True, 'reg_all': 0.03}, {'n_factors': 50, 'n_epochs': 60, 'biased': False, 'reg_all': 0.01}, {'n_factors': 50, 'n_epochs': 60, 'biased': False, 'reg_all': 0.02}, {'n_factors': 50, 'n_epochs': 60, 'biased': False, 'reg_all': 0.03}, {'n_factors': 70, 'n_epochs': 20, 'biased': True, 'reg_all': 0.01}, {'n_factors': 70, 'n_epochs': 20, 'biased': True, 'reg_all': 0.02}, {'n_factors': 70, 'n_epochs': 20, 'biased': True, 'reg_all': 0.03}, {'n_factors': 70, 'n_epochs': 20, 'biased': False, 'reg_all': 0.01}, {'n_factors': 70, 'n_epochs': 20, 'biased': False, 'reg_all': 0.02}, {'n_factors': 70, 'n_epochs': 20, 'biased': False, 'reg_all': 0.03}, {'n_factors': 70, 'n_epochs': 40, 'biased': True, 'reg_all': 0.01}, {'n_factors': 70, 'n_epochs': 40, 'biased': True, 'reg_all': 0.02}, {'n_factors': 70, 'n_epochs': 40, 'biased': True, 'reg_all': 0.03}, {'n_factors': 70, 'n_epochs': 40, 'biased': False, 'reg_all': 0.01}, {'n_factors': 70, 'n_epochs': 40, 'biased': False, 'reg_all': 0.02}, {'n_factors': 70, 'n_epochs': 40, 'biased': False, 'reg_all': 0.03}, {'n_factors': 70, 'n_epochs': 60, 'biased': True, 'reg_all': 0.01}, {'n_factors': 70, 'n_epochs': 60, 'biased': True, 'reg_all': 0.02}, {'n_factors': 70, 'n_epochs': 60, 'biased': True, 'reg_all': 0.03}, {'n_factors': 70, 'n_epochs': 60, 'biased': False, 'reg_all': 0.01}, {'n_factors': 70, 'n_epochs': 60, 'biased': False, 'reg_all': 0.02}, {'n_factors': 70, 'n_epochs': 60, 'biased': False, 'reg_all': 0.03}, {'n_factors': 100, 'n_epochs': 20, 'biased': True, 'reg_all': 0.01}, {'n_factors': 100, 'n_epochs': 20, 'biased': True, 'reg_all': 0.02}, {'n_factors': 100, 'n_epochs': 20, 'biased': True, 'reg_all': 0.03}, {'n_factors': 100, 'n_epochs': 20, 'biased': False, 'reg_all': 0.01}, {'n_factors': 100, 'n_e ...

# %%
grid_search.evaluate(data)
# Out:
# ------------
# Parameters combination 1 of 90
# params:  {'n_factors': 10, 'n_epochs': 20, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9483
# Mean MAE : 0.7491
# ------------
# ------------
# Parameters combination 2 of 90
# params:  {'n_factors': 10, 'n_epochs': 20, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9493
# Mean MAE : 0.7503
# ------------
# ------------
# Parameters combination 3 of 90
# params:  {'n_factors': 10, 'n_epochs': 20, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9489
# Mean MAE : 0.7505
# ------------
# ------------
# Parameters combination 4 of 90
# params:  {'n_factors': 10, 'n_epochs': 20, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9770
# Mean MAE : 0.7653
# ------------
# ------------
# Parameters combination 5 of 90
# params:  {'n_factors': 10, 'n_epochs': 20, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9792
# Mean MAE : 0.7684
# ------------
# ------------
# Parameters combination 6 of 90
# params:  {'n_factors': 10, 'n_epochs': 20, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9791
# Mean MAE : 0.7690
# ------------
# ------------
# Parameters combination 7 of 90
# params:  {'n_factors': 10, 'n_epochs': 40, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9617
# Mean MAE : 0.7537
# ------------
# ------------
# Parameters combination 8 of 90
# params:  {'n_factors': 10, 'n_epochs': 40, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9557
# Mean MAE : 0.7513
# ------------
# ------------
# Parameters combination 9 of 90
# params:  {'n_factors': 10, 'n_epochs': 40, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9539
# Mean MAE : 0.7513
# ------------
# ------------
# Parameters combination 10 of 90
# params:  {'n_factors': 10, 'n_epochs': 40, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9799
# Mean MAE : 0.7670
# ------------
# ------------
# Parameters combination 11 of 90
# params:  {'n_factors': 10, 'n_epochs': 40, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9720
# Mean MAE : 0.7630
# ------------
# ------------
# Parameters combination 12 of 90
# params:  {'n_factors': 10, 'n_epochs': 40, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9658
# Mean MAE : 0.7588
# ------------
# ------------
# Parameters combination 13 of 90
# params:  {'n_factors': 10, 'n_epochs': 60, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9983
# Mean MAE : 0.7782
# ------------
# ------------
# Parameters combination 14 of 90
# params:  {'n_factors': 10, 'n_epochs': 60, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9852
# Mean MAE : 0.7699
# ------------
# ------------
# Parameters combination 15 of 90
# params:  {'n_factors': 10, 'n_epochs': 60, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9709
# Mean MAE : 0.7606
# ------------
# ------------
# Parameters combination 16 of 90
# params:  {'n_factors': 10, 'n_epochs': 60, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0045
# Mean MAE : 0.7807
# ------------
# ------------
# Parameters combination 17 of 90
# params:  {'n_factors': 10, 'n_epochs': 60, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9916
# Mean MAE : 0.7735
# ------------
# ------------
# Parameters combination 18 of 90
# params:  {'n_factors': 10, 'n_epochs': 60, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9832
# Mean MAE : 0.7685
# ------------
# ------------
# Parameters combination 19 of 90
# params:  {'n_factors': 50, 'n_epochs': 20, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9534
# Mean MAE : 0.7532
# ------------
# ------------
# Parameters combination 20 of 90
# params:  {'n_factors': 50, 'n_epochs': 20, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9517
# Mean MAE : 0.7523
# ------------
# ------------
# Parameters combination 21 of 90
# params:  {'n_factors': 50, 'n_epochs': 20, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9509
# Mean MAE : 0.7522
# ------------
# ------------
# Parameters combination 22 of 90
# params:  {'n_factors': 50, 'n_epochs': 20, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9887
# Mean MAE : 0.7777
# ------------
# ------------
# Parameters combination 23 of 90
# params:  {'n_factors': 50, 'n_epochs': 20, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9855
# Mean MAE : 0.7764
# ------------
# ------------
# Parameters combination 24 of 90
# params:  {'n_factors': 50, 'n_epochs': 20, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9825
# Mean MAE : 0.7737
# ------------
# ------------
# Parameters combination 25 of 90
# params:  {'n_factors': 50, 'n_epochs': 40, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9869
# Mean MAE : 0.7739
# ------------
# ------------
# Parameters combination 26 of 90
# params:  {'n_factors': 50, 'n_epochs': 40, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9724
# Mean MAE : 0.7644
# ------------
# ------------
# Parameters combination 27 of 90
# params:  {'n_factors': 50, 'n_epochs': 40, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9633
# Mean MAE : 0.7570
# ------------
# ------------
# Parameters combination 28 of 90
# params:  {'n_factors': 50, 'n_epochs': 40, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0125
# Mean MAE : 0.7963
# ------------
# ------------
# Parameters combination 29 of 90
# params:  {'n_factors': 50, 'n_epochs': 40, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9991
# Mean MAE : 0.7861
# ------------
# ------------
# Parameters combination 30 of 90
# params:  {'n_factors': 50, 'n_epochs': 40, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9818
# Mean MAE : 0.7732
# ------------
# ------------
# Parameters combination 31 of 90
# params:  {'n_factors': 50, 'n_epochs': 60, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0305
# Mean MAE : 0.8065
# ------------
# ------------
# Parameters combination 32 of 90
# params:  {'n_factors': 50, 'n_epochs': 60, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9996
# Mean MAE : 0.7838
# ------------
# ------------
# Parameters combination 33 of 90
# params:  {'n_factors': 50, 'n_epochs': 60, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9821
# Mean MAE : 0.7705
# ------------
# ------------
# Parameters combination 34 of 90
# params:  {'n_factors': 50, 'n_epochs': 60, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0528
# Mean MAE : 0.8260
# ------------
# ------------
# Parameters combination 35 of 90
# params:  {'n_factors': 50, 'n_epochs': 60, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 1.0235
# Mean MAE : 0.8037
# ------------
# ------------
# Parameters combination 36 of 90
# params:  {'n_factors': 50, 'n_epochs': 60, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 1.0061
# Mean MAE : 0.7908
# ------------
# ------------
# Parameters combination 37 of 90
# params:  {'n_factors': 70, 'n_epochs': 20, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9549
# Mean MAE : 0.7543
# ------------
# ------------
# Parameters combination 38 of 90
# params:  {'n_factors': 70, 'n_epochs': 20, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9524
# Mean MAE : 0.7527
# ------------
# ------------
# Parameters combination 39 of 90
# params:  {'n_factors': 70, 'n_epochs': 20, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9511
# Mean MAE : 0.7524
# ------------
# ------------
# Parameters combination 40 of 90
# params:  {'n_factors': 70, 'n_epochs': 20, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9952
# Mean MAE : 0.7849
# ------------
# ------------
# Parameters combination 41 of 90
# params:  {'n_factors': 70, 'n_epochs': 20, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9895
# Mean MAE : 0.7802
# ------------
# ------------
# Parameters combination 42 of 90
# params:  {'n_factors': 70, 'n_epochs': 20, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9873
# Mean MAE : 0.7786
# ------------
# ------------
# Parameters combination 43 of 90
# params:  {'n_factors': 70, 'n_epochs': 40, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9866
# Mean MAE : 0.7748
# ------------
# ------------
# Parameters combination 44 of 90
# params:  {'n_factors': 70, 'n_epochs': 40, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9725
# Mean MAE : 0.7646
# ------------
# ------------
# Parameters combination 45 of 90
# params:  {'n_factors': 70, 'n_epochs': 40, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9619
# Mean MAE : 0.7575
# ------------
# ------------
# Parameters combination 46 of 90
# params:  {'n_factors': 70, 'n_epochs': 40, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0226
# Mean MAE : 0.8057
# ------------
# ------------
# Parameters combination 47 of 90
# params:  {'n_factors': 70, 'n_epochs': 40, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 1.0023
# Mean MAE : 0.7902
# ------------
# ------------
# Parameters combination 48 of 90
# params:  {'n_factors': 70, 'n_epochs': 40, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9904
# Mean MAE : 0.7814
# ------------
# ------------
# Parameters combination 49 of 90
# params:  {'n_factors': 70, 'n_epochs': 60, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0195
# Mean MAE : 0.7996
# ------------
# ------------
# Parameters combination 50 of 90
# params:  {'n_factors': 70, 'n_epochs': 60, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9974
# Mean MAE : 0.7833
# ------------
# ------------
# Parameters combination 51 of 90
# params:  {'n_factors': 70, 'n_epochs': 60, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9814
# Mean MAE : 0.7714
# ------------
# ------------
# Parameters combination 52 of 90
# params:  {'n_factors': 70, 'n_epochs': 60, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0548
# Mean MAE : 0.8299
# ------------
# ------------
# Parameters combination 53 of 90
# params:  {'n_factors': 70, 'n_epochs': 60, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 1.0253
# Mean MAE : 0.8076
# ------------
# ------------
# Parameters combination 54 of 90
# params:  {'n_factors': 70, 'n_epochs': 60, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 1.0043
# Mean MAE : 0.7922
# ------------
# ------------
# Parameters combination 55 of 90
# params:  {'n_factors': 100, 'n_epochs': 20, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9598
# Mean MAE : 0.7587
# ------------
# ------------
# Parameters combination 56 of 90
# params:  {'n_factors': 100, 'n_epochs': 20, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9550
# Mean MAE : 0.7546
# ------------
# ------------
# Parameters combination 57 of 90
# params:  {'n_factors': 100, 'n_epochs': 20, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9528
# Mean MAE : 0.7534
# ------------
# ------------
# Parameters combination 58 of 90
# params:  {'n_factors': 100, 'n_epochs': 20, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0052
# Mean MAE : 0.7933
# ------------
# ------------
# Parameters combination 59 of 90
# params:  {'n_factors': 100, 'n_epochs': 20, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 1.0007
# Mean MAE : 0.7905
# ------------
# ------------
# Parameters combination 60 of 90
# params:  {'n_factors': 100, 'n_epochs': 20, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9949
# Mean MAE : 0.7861
# ------------
# ------------
# Parameters combination 61 of 90
# params:  {'n_factors': 100, 'n_epochs': 40, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9868
# Mean MAE : 0.7764
# ------------
# ------------
# Parameters combination 62 of 90
# params:  {'n_factors': 100, 'n_epochs': 40, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9749
# Mean MAE : 0.7677
# ------------
# ------------
# Parameters combination 63 of 90
# params:  {'n_factors': 100, 'n_epochs': 40, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9607
# Mean MAE : 0.7575
# ------------
# ------------
# Parameters combination 64 of 90
# params:  {'n_factors': 100, 'n_epochs': 40, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0305
# Mean MAE : 0.8149
# ------------
# ------------
# Parameters combination 65 of 90
# params:  {'n_factors': 100, 'n_epochs': 40, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 1.0089
# Mean MAE : 0.7964
# ------------
# ------------
# Parameters combination 66 of 90
# params:  {'n_factors': 100, 'n_epochs': 40, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9963
# Mean MAE : 0.7874
# ------------
# ------------
# Parameters combination 67 of 90
# params:  {'n_factors': 100, 'n_epochs': 60, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0085
# Mean MAE : 0.7921
# ------------
# ------------
# Parameters combination 68 of 90
# params:  {'n_factors': 100, 'n_epochs': 60, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9908
# Mean MAE : 0.7803
# ------------
# ------------
# Parameters combination 69 of 90
# params:  {'n_factors': 100, 'n_epochs': 60, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9734
# Mean MAE : 0.7667
# ------------
# ------------
# Parameters combination 70 of 90
# params:  {'n_factors': 100, 'n_epochs': 60, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0502
# Mean MAE : 0.8283
# ------------
# ------------
# Parameters combination 71 of 90
# params:  {'n_factors': 100, 'n_epochs': 60, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 1.0211
# Mean MAE : 0.8072
# ------------
# ------------
# Parameters combination 72 of 90
# params:  {'n_factors': 100, 'n_epochs': 60, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 1.0044
# Mean MAE : 0.7942
# ------------
# ------------
# Parameters combination 73 of 90
# params:  {'n_factors': 200, 'n_epochs': 20, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9695
# Mean MAE : 0.7662
# ------------
# ------------
# Parameters combination 74 of 90
# params:  {'n_factors': 200, 'n_epochs': 20, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9621
# Mean MAE : 0.7609
# ------------
# ------------
# Parameters combination 75 of 90
# params:  {'n_factors': 200, 'n_epochs': 20, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9580
# Mean MAE : 0.7578
# ------------
# ------------
# Parameters combination 76 of 90
# params:  {'n_factors': 200, 'n_epochs': 20, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0468
# Mean MAE : 0.8306
# ------------
# ------------
# Parameters combination 77 of 90
# params:  {'n_factors': 200, 'n_epochs': 20, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 1.0364
# Mean MAE : 0.8228
# ------------
# ------------
# Parameters combination 78 of 90
# params:  {'n_factors': 200, 'n_epochs': 20, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 1.0286
# Mean MAE : 0.8169
# ------------
# ------------
# Parameters combination 79 of 90
# params:  {'n_factors': 200, 'n_epochs': 40, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9856
# Mean MAE : 0.7775
# ------------
# ------------
# Parameters combination 80 of 90
# params:  {'n_factors': 200, 'n_epochs': 40, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9710
# Mean MAE : 0.7659
# ------------
# ------------
# Parameters combination 81 of 90
# params:  {'n_factors': 200, 'n_epochs': 40, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9607
# Mean MAE : 0.7586
# ------------
# ------------
# Parameters combination 82 of 90
# params:  {'n_factors': 200, 'n_epochs': 40, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0600
# Mean MAE : 0.8436
# ------------
# ------------
# Parameters combination 83 of 90
# params:  {'n_factors': 200, 'n_epochs': 40, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 1.0353
# Mean MAE : 0.8216
# ------------
# ------------
# Parameters combination 84 of 90
# params:  {'n_factors': 200, 'n_epochs': 40, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 1.0202
# Mean MAE : 0.8101
# ------------
# ------------
# Parameters combination 85 of 90
# params:  {'n_factors': 200, 'n_epochs': 60, 'biased': True, 'reg_all': 0.01}
# ------------
# Mean RMSE: 0.9908
# Mean MAE : 0.7814
# ------------
# ------------
# Parameters combination 86 of 90
# params:  {'n_factors': 200, 'n_epochs': 60, 'biased': True, 'reg_all': 0.02}
# ------------
# Mean RMSE: 0.9736
# Mean MAE : 0.7686
# ------------
# ------------
# Parameters combination 87 of 90
# params:  {'n_factors': 200, 'n_epochs': 60, 'biased': True, 'reg_all': 0.03}
# ------------
# Mean RMSE: 0.9642
# Mean MAE : 0.7607
# ------------
# ------------
# Parameters combination 88 of 90
# params:  {'n_factors': 200, 'n_epochs': 60, 'biased': False, 'reg_all': 0.01}
# ------------
# Mean RMSE: 1.0635
# Mean MAE : 0.8450
# ------------
# ------------
# Parameters combination 89 of 90
# params:  {'n_factors': 200, 'n_epochs': 60, 'biased': False, 'reg_all': 0.02}
# ------------
# Mean RMSE: 1.0342
# Mean MAE : 0.8210
# ------------
# ------------
# Parameters combination 90 of 90
# params:  {'n_factors': 200, 'n_epochs': 60, 'biased': False, 'reg_all': 0.03}
# ------------
# Mean RMSE: 1.0162
# Mean MAE : 0.8064
# ------------

# %%
grid_search.best_params['RMSE']
# Out:
# {'biased': True, 'n_epochs': 20, 'n_factors': 10, 'reg_all': 0.01}

# %%
grid_search.best_params['MAE']
# Out:
# {'biased': True, 'n_epochs': 20, 'n_factors': 10, 'reg_all': 0.01}

# %%
results = pd.DataFrame.from_dict(grid_search.cv_results)

# %%
results.to_csv('data/results.csv')

# %%
results = pd.read_csv('data/results.csv')
results
# Out:
#     Unnamed: 0       MAE      RMSE  n_epochs  n_factors  \
# 0            0  0.749063  0.948313        20         10
# 1            1  0.750258  0.949310        20         10
# 2            2  0.750506  0.948872        20         10
# 3            3  0.765346  0.977037        20         10
# 4            4  0.768364  0.979233        20         10
# 5            5  0.768952  0.979095        20         10
# 6            6  0.753730  0.961738        40         10
# 7            7  0.751323  0.955722        40         10
# 8            8  0.751270  0.953942        40         10
# 9            9  0.767020  0.979931        40         10
# 10          10  0.762977  0.972029        40         10
# 11          11  0.758767  0.965836        40         10
# 12          12  0.778170  0.998313        60         10
# 13          13  0.769909  0.985188        60         10
# 14          14  0.760612  0.970868        60         10
# 15          15  0.780664  1.004462        60         10
# 16          16  0.773461  0.991610        60         10
# 17          17  0.768524  0.983213        60         10
# 18          18  0.753245  0.953402        20         50
# 19          19  0.752254  0.951676        20         50
# 20          20  0.752195  0.950892        20         50
# 21          21  0.777671  0.988720        20         50
# 22          22  0.776351  0.985539        20         50
# 23          23  0.773655  0.982454        20         50
# 24          24  0.773943  0.986905        40         50
# 25          25  0.764434  0.972382        40         50
# 26          26  0.756958  0.963286        40         50
# 27          27  0.796340  1.012514        40         50
# 28          28  0.786134  0.999065        40         50
# 29          29  0.773183  0.981811        40         50
# ..         ...       ...       ...       ...        ...
# 60          60  0.776413  0.986775        40        100
# 61          61  0.767711  0.974935        40        100
# 62          62  0.757540  0.960714        40        100
# 63          63  0.814940  1.030530        40        100
# 64          64  0.796373  1.008859        40        100
# 65          65  0.787441  0.996260        40        100
# 66          66  0.792109  1.008459        60        100
# 67          67  0.780288  0.990780        60        100
# 68          68  0.766677  0.973438        60        100
# 69          69  0.828298  1.050241        60        100
# 70          70  0.807216  1.021132        60        100
# 71          71  0.794159  1.004392        60        100
# 72          72  0.766231  0.969494        20        200
# 73          73  0.760887  0.962066        20        200
# 74          74  0.757825  0.958016        20        200
# 75          75  0.830610  1.046804        20        200
# 76          76  0.822804  1.036430        20        200
# 77          77  0.816904  1.028604        20        200
# 78          78  0.777471  0.985592        40        200
# 79          79  0.765883  0.970993        40        200
# 80          80  0.758555  0.960653        40        200
# 81          81  0.843618  1.059951        40        200
# 82          82  0.821609  1.035341        40        200
# 83          83  0.810098  1.020161        40        200
# 84          84  0.781403  0.990756        60        200
# 85          85  0.768595  0.973629        60        200
# 86          86  0.760675  0.964220        60        200
# 87          87  0.844980  1.063533        60        200
# 88          88  0.821016  1.034185        60        200
# 89          89  0.806353  1.016249        60        200
#
#                                                params  \
# 0   {'n_factors': 10, 'n_epochs': 20, 'biased': Tr...
# 1   {'n_factors': 10, 'n_epochs': 20, 'biased': Tr...
# 2   {'n_factors': 10, 'n_epochs': 20, 'biased': Tr...
# 3   {'n_factors': 10, 'n_epochs': 20, 'biased': Fa...
# 4   {'n_factors': 10, 'n_epochs': 20, 'biased': Fa...
# 5   {'n_factors': 10, 'n_epochs': 20, 'biased': Fa...
# 6   {'n_factors': 10, 'n_epochs': 40, 'biased': Tr...
# 7   {'n_factors': 10, 'n_epochs': 40, 'biased': Tr...
# 8   {'n_factors': 10, 'n_epochs': 40, 'biased': Tr...
# 9   {'n_factors': 10, 'n_epochs': 40, 'biased': Fa...
# 10  {'n_factors': 10, 'n_epochs': 40, 'biased': Fa...
# 11  {'n_factors': 10, 'n_epochs': 40, 'biased': Fa...
# 12  {'n_factors': 10, 'n_epochs': 60, 'biased': Tr...
# 13  {'n_factors': 10, 'n_epochs': 60, 'biased': Tr...
# 14  {'n_factors': 10, 'n_epochs': 60, 'biased': Tr...
# 15  {'n_factors': 10, 'n_epochs': 60, 'biased': Fa...
# 16  {'n_factors': 10, 'n_epochs': 60, 'biased': Fa...
# 17  {'n_factors': 10, 'n_epochs': 60, 'biased': Fa...
# 18  {'n_factors': 50, 'n_epochs': 20, 'biased': Tr...
# 19  {'n_factors': 50, 'n_epochs': 20, 'biased': Tr...
# 20  {'n_factors': 50, 'n_epochs': 20, 'biased': Tr...
# 21  {'n_factors': 50, 'n_epochs': 20, 'biased': Fa...
# 22  {'n_factors': 50, 'n_epochs': 20, 'biased': Fa...
# 23  {'n_factors': 50, 'n_epochs': 20, 'biased': Fa...
# 24  {'n_factors': 50, 'n_epochs': 40, 'biased': Tr...
# 25  {'n_factors': 50, 'n_epochs': 40, 'biased': Tr...
# 26  {'n_factors': 50, 'n_epochs': 40, 'biased': Tr...
# 27  {'n_factors': 50, 'n_epochs': 40, 'biased': Fa...
# 28  {'n_factors': 50, 'n_epochs': 40, 'biased': Fa...
# 29  {'n_factors': 50, 'n_epochs': 40, 'biased': Fa...
# ..                                                ...
# 60  {'n_factors': 100, 'n_epochs': 40, 'biased': T...
# 61  {'n_factors': 100, 'n_epochs': 40, 'biased': T...
# 62  {'n_factors': 100, 'n_epochs': 40, 'biased': T...
# 63  {'n_factors': 100, 'n_epochs': 40, 'biased': F...
# 64  {'n_factors': 100, 'n_epochs': 40, 'biased': F...
# 65  {'n_factors': 100, 'n_epochs': 40, 'biased': F...
# 66  {'n_factors': 100, 'n_epochs': 60, 'biased': T...
# 67  {'n_factors': 100, 'n_epochs': 60, 'biased': T...
# 68  {'n_factors': 100, 'n_epochs': 60, 'biased': T...
# 69  {'n_factors': 100, 'n_epochs': 60, 'biased': F...
# 70  {'n_factors': 100, 'n_epochs': 60, 'biased': F...
# 71  {'n_factors': 100, 'n_epochs': 60, 'biased': F...
# 72  {'n_factors': 200, 'n_epochs': 20, 'biased': T...
# 73  {'n_factors': 200, 'n_epochs': 20, 'biased': T...
# 74  {'n_factors': 200, 'n_epochs': 20, 'biased': T...
# 75  {'n_factors': 200, 'n_epochs': 20, 'biased': F...
# 76  {'n_factors': 200, 'n_epochs': 20, 'biased': F...
# 77  {'n_factors': 200, 'n_epochs': 20, 'biased': F...
# 78  {'n_factors': 200, 'n_epochs': 40, 'biased': T...
# 79  {'n_factors': 200, 'n_epochs': 40, 'biased': T...
# 80  {'n_factors': 200, 'n_epochs': 40, 'biased': T...
# 81  {'n_factors': 200, 'n_epochs': 40, 'biased': F...
# 82  {'n_factors': 200, 'n_epochs': 40, 'biased': F...
# 83  {'n_factors': 200, 'n_epochs': 40, 'biased': F...
# 84  {'n_factors': 200, 'n_epochs': 60, 'biased': T...
# 85  {'n_factors': 200, 'n_epochs': 60, 'biased': T...
# 86  {'n_factors': 200, 'n_epochs': 60, 'biased': T...
# 87  {'n_factors': 200, 'n_epochs': 60, 'biased': F...
# 88  {'n_factors': 200, 'n_epochs': 60, 'biased': F...
# 89  {'n_factors': 200, 'n_epochs': 60, 'biased': F...
#
#                                                scores
# 0   {'RMSE': 0.94831340289822119, 'MAE': 0.7490631...
# 1   {'RMSE': 0.94930958352407002, 'MAE': 0.7502579...
# 2   {'RMSE': 0.9488721774402662, 'MAE': 0.75050611...
# 3   {'RMSE': 0.97703720565431973, 'MAE': 0.7653462...
# 4   {'RMSE': 0.97923343576997302, 'MAE': 0.7683635...
# 5   {'RMSE': 0.97909459030187329, 'MAE': 0.7689516...
# 6   {'RMSE': 0.96173807686370871, 'MAE': 0.7537295...
# 7   {'RMSE': 0.95572219250989821, 'MAE': 0.7513228...
# 8   {'RMSE': 0.95394181118022869, 'MAE': 0.7512704...
# 9   {'RMSE': 0.97993059262316762, 'MAE': 0.7670200...
# 10  {'RMSE': 0.97202930640876606, 'MAE': 0.7629766...
# 11  {'RMSE': 0.96583569715323569, 'MAE': 0.7587669...
# 12  {'RMSE': 0.99831284858452829, 'MAE': 0.7781703...
# 13  {'RMSE': 0.98518833088873348, 'MAE': 0.7699087...
# 14  {'RMSE': 0.9708679038949124, 'MAE': 0.76061187...
# 15  {'RMSE': 1.004461503153143, 'MAE': 0.780663933...
# 16  {'RMSE': 0.99160984799551566, 'MAE': 0.7734612...
# 17  {'RMSE': 0.98321275790017126, 'MAE': 0.7685238...
# 18  {'RMSE': 0.95340191245721972, 'MAE': 0.7532450...
# 19  {'RMSE': 0.95167576035424184, 'MAE': 0.7522544...
# 20  {'RMSE': 0.95089159000594803, 'MAE': 0.7521949...
# 21  {'RMSE': 0.98871950061627656, 'MAE': 0.7776713...
# 22  {'RMSE': 0.98553851632355594, 'MAE': 0.7763507...
# 23  {'RMSE': 0.98245353962164661, 'MAE': 0.7736550...
# 24  {'RMSE': 0.98690482129682766, 'MAE': 0.7739426...
# 25  {'RMSE': 0.97238210131405556, 'MAE': 0.7644337...
# 26  {'RMSE': 0.96328615672983553, 'MAE': 0.7569580...
# 27  {'RMSE': 1.0125143231098033, 'MAE': 0.79633950...
# 28  {'RMSE': 0.99906452722883765, 'MAE': 0.7861342...
# 29  {'RMSE': 0.98181110892344869, 'MAE': 0.7731833...
# ..                                                ...
# 60  {'RMSE': 0.98677538017636923, 'MAE': 0.7764126...
# 61  {'RMSE': 0.97493508855459177, 'MAE': 0.7677109...
# 62  {'RMSE': 0.96071448786771663, 'MAE': 0.7575403...
# 63  {'RMSE': 1.0305301355253658, 'MAE': 0.81494026...
# 64  {'RMSE': 1.0088588277265713, 'MAE': 0.79637274...
# 65  {'RMSE': 0.99625959915405105, 'MAE': 0.7874408...
# 66  {'RMSE': 1.0084591881066145, 'MAE': 0.79210890...
# 67  {'RMSE': 0.99077951545884146, 'MAE': 0.7802882...
# 68  {'RMSE': 0.97343826489644114, 'MAE': 0.7666774...
# 69  {'RMSE': 1.0502414515969343, 'MAE': 0.82829795...
# 70  {'RMSE': 1.0211324392259291, 'MAE': 0.80721647...
# 71  {'RMSE': 1.0043922230636535, 'MAE': 0.79415875...
# 72  {'RMSE': 0.96949365193226966, 'MAE': 0.7662309...
# 73  {'RMSE': 0.96206567764605644, 'MAE': 0.7608869...
# 74  {'RMSE': 0.9580159855745678, 'MAE': 0.75782491...
# 75  {'RMSE': 1.0468044467836155, 'MAE': 0.83060977...
# 76  {'RMSE': 1.0364298071087266, 'MAE': 0.82280430...
# 77  {'RMSE': 1.0286035539444782, 'MAE': 0.81690371...
# 78  {'RMSE': 0.98559223307471666, 'MAE': 0.7774709...
# 79  {'RMSE': 0.97099287693007319, 'MAE': 0.7658831...
# 80  {'RMSE': 0.96065311656168051, 'MAE': 0.7585552...
# 81  {'RMSE': 1.0599514274460182, 'MAE': 0.84361760...
# 82  {'RMSE': 1.0353410633694438, 'MAE': 0.82160922...
# 83  {'RMSE': 1.020160747594522, 'MAE': 0.810098083...
# 84  {'RMSE': 0.99075579535853842, 'MAE': 0.7814028...
# 85  {'RMSE': 0.9736294152608882, 'MAE': 0.76859470...
# 86  {'RMSE': 0.96422037856517984, 'MAE': 0.7606746...
# 87  {'RMSE': 1.0635327493729512, 'MAE': 0.84498015...
# 88  {'RMSE': 1.0341852917937151, 'MAE': 0.82101597...
# 89  {'RMSE': 1.0162490967535911, 'MAE': 0.80635252...
#
# [90 rows x 7 columns]
